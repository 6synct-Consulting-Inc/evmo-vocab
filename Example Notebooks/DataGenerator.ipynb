# %% [markdown]
# # Importing Libraries
# ## Import the Python libraries required for data science and data visualization and for reading data.

# %%
# Import libraries
import os
import json
import re

# Import data science / mathematics libraries
import pandas as pd
import random

# Import other utilities
from datetime import date
import datetime as dt

# %%
# Set the working directories
wd = os.getcwd()

par_dir = os.path.abspath(os.path.join(wd, os.pardir))
data_dir = os.path.join(par_dir, "Example Notebooks")

# Set the date (for map image filenames)
today = date.today()

# %% [markdown]
# ## Load seed data

# %%
seed_path = os.path.join(data_dir, "data_generator_seed.json")

with open(seed_path, 'r') as file:
    seed_data = json.load(file)

# %%
# bev_data_path = "BEV Data (Combined).xlsx"
# equip_list = pd.read_excel(os.path.join(tco_data_dir, bev_data_path), sheet_name="Equipment List")

# %% [markdown]
# ## Generate example data sets

# %%
random.choice(seed_data["Category"])
# Out:
# 'BEV Light Truck'
